# %%
#!/usr/bin/env python
# coding: utf-8

# In[2]:


import rebound, numpy as np, matplotlib as mpl
#mpl.use('Agg') # found here:https://stackoverflow.com/questions/4931376/generating-matplotlib-graphs-without-a-running-x-server
import matplotlib.pyplot as plt, time as tiempo, math, sys

sim = rebound.Simulation()
tau = 2*np.pi


# In[3]:


def ttor(R0 = 5e-4): #two to one resonance
    sim = rebound.Simulation()
    #sim.units = ('yr', 'AU', 'Msun') #sets G=4pi^2 so AU, earth years, solar masses
    #R0 = 5**(1/3)*0.01
    sim.add(m=1) #creates a star of mass 1
    sim.add(m=1e-3, a=1, r=R0)  #creates a planet with mass 0.001 at 1 AU
    sim.add(m=1e-3, a=2**(2/3), f=np.pi, r=R0) 
    return sim

def tttr(R0 = 5e-4): #two to three resonance
    sim = rebound.Simulation()
    #sim.units = ('yr', 'AU', 'Msun') #sets G=4pi^2 so AU, earth years, solar masses
    #R0 = 0.01
    sim.add(m=1) #creates a star of mass 1
    sim.add(m=1e-3, a=2**(2/3), r=R0)  #creates a planet with mass 0.001 at 1 AU
    sim.add(m=1e-3, a=3**(2/3), f=np.pi, r=R0) 
    return sim

def nor(R0 = 5e-4): #no resonance (initially at least)
    sim = rebound.Simulation()
    #sim.units = ('yr', 'AU', 'Msun') #sets G=4pi^2 so AU, earth years, solar masses
    sim.add(m=1) #creates a star of mass 1
    #R0 = .02
    sim.add(m=1e-3, a=1, r=R0)  #creates a planet with mass 0.001 at 1 AU
    sim.add(m=1e-3, a=1.8, f=np.pi, r=R0) #use .1 mass to show the planets having a large effect on each other
    return sim
    
def resonance_counter(data, base = 1):
    innerplanetcount = 0
    outerplanetcount = 0
    for i, x in enumerate(np.delete(data,len(data)-1,0)):
        if x[0] < 0 and data[i+1][0] > 0:
            innerplanetcount += 1
        if x[1] < 0 and data[i+1][1] > 0:
            outerplanetcount += 1
    R = innerplanetcount/outerplanetcount
    print(R)
    R = R*base
    if R == int(R):
        R = int(R)
    print("The outer planet revolved", outerplanetcount, "times.")
    print("The inner planet revolved", innerplanetcount, "times.")
    print("They are in a {}:{} resonance.".format(base, R))
     
def rand_powerlaw(slope, min_v, max_v): #some distribution functions
    #https://rebound.readthedocs.io/en/latest/ipython/PrimordialEarth.html
    y = np.random.uniform()
    pow_max = pow(max_v, slope+1.)
    pow_min = pow(min_v, slope+1.)
    return pow((pow_max-pow_min)*y + pow_min, 1./(slope+1.))
def rand_uniform(minimum, maximum):
    return np.random.uniform()*(maximum-minimum)+minimum
def rand_rayleigh(sigma):
    return sigma*np.sqrt(-2*np.log(np.random.uniform()))

def quickplot(sim): #this uses matplotlib to plot the orbit, instead of rebound
    coords = np.zeros((2,sim.N))
    for i in range(sim.N):
        coords[0][i], coords[1][i] = sim.particles[i].x, sim.particles[i].y
    fig, ax = plt.subplots()
    ax.axis('equal')
    ax.scatter(coords[0],coords[1],marker=".",linewidth=0)
    for i in range(sim.N_active):
        ax.scatter(sim.particles[i].x,sim.particles[i].y); # Planet
        
def my_merge(sim_pointer, collided_particles_index):
    
    #https://rebound.readthedocs.io/en/latest/ipython/User_Defined_Collision_Resolve.html
    #or
    #https://rebound.readthedocs.io/en/latest/ipython_examples/User_Defined_Collision_Resolve/
    
    sim = sim_pointer.contents # retreive the standard simulation object
    ps = sim.particles # easy access to list of particles

    i1 = collided_particles_index.p1   # Note that p1 < p2 is not guaranteed.
    j1 = collided_particles_index.p2
    
    if ps[i1]==0 and ps[j1]==0:
        print("both are asteroids")
        return 0
    else:
        if ps[i1].m==0: #assigns k as the planet with mass and l as the particle w/o mass
            k=j1
            l=i1
            destroyi1=True
        if ps[j1].m==0: #assigns k as the planet with mass and l as the particle w/o mass
            k=i1
            l=j1
            destroyi1=False
            
        '''fig, ax = rebound.OrbitPlot(sim, xlim = (-1.3, 1.3), ylim = (-1.3, 1.3), color=['blue', 'green'])
        ax.set_title("Merging particle {} into {}".format(j, i))
        ax.text(ps[k].x, ps[k].y, "1");
        ax.text(ps[l].x, ps[l].y, "2")'''
        # So we plot the scenario exactly at the timestep that the collision function is triggered
        
        #print("merging particle", k,'into particle', l) #use this to know when collisions occur
        
        #particle_mass = Mtot_disk/N_pl
        particle_mass=1e-5
        particle_radius = 1e-5
        # Merging Logic
        total_mass = ps[k].m + particle_mass
        #merged_planet = (ps[i] * ps[i].m + ps[j] * ps[j].m)/total_mass # conservation of momentum

        # merged radius assuming a uniform density
        merged_radius = (ps[k].r**3 + particle_radius**3)**(1/3)

        #ps[k] = merged_planet   # update p1's state vector (mass and radius will need corrections)
        ps[k].m = total_mass    # update to total mass
        ps[k].r = merged_radius # update to joined radius
        
        #sim.ri_whfast.recalculate_coordinates_this_timestep = 1 #after adding mass
        #to a particle, we must recalculate Jacobi coordinates in order to recieve
        #physical values. Note that this code should be commented out if safemode is on.
        
        if destroyi1:
            return 1 #destroys p1, which is the particle w/o mass
        else:
            return 2 #destroys p2, which is the particle w/o mass
     
    
def masslist_txt(masslist,filepath,sim = None, write_type = 'a'):
    """
    Saves the masslists into a formatted txt file.
    """
    
    def avg(lst):
        sum = 0
        for i in lst:
            sum += i
        return sum / len(lst)

    masslistcopy = masslist.copy() # Don't want to edit the original data
    percentlist = list()
    message = ''
    message+="Inner planet mass\tOuter planet mass\tPercent Difference\tSeed\n"
    for data in masslistcopy[1:]:
        data = data.copy() #comment out this line to not have the original list change
        percentdif = abs((data[0]-data[1])/data[0])*100
        roundedpercentdif = round(percentdif,2)
        percentlist.append(percentdif)
        data.insert(2,percentdif)
        for j in data:
            message += str(j)
            message +='\t'
        message +='\n'   
    message+= "\nAverage percent difference= {}.\n\n".format(avg(percentlist))
    with open(filepath,write_type) as file:
        file.write(sim+'\n')
        file.write(message)

def masslist_txt_append(masslist, filepath,sim = None,write_type = 'a', **kwargs):
    """
    Saves the masslists into a formatted txt file. This is similar to masslist_txt except 
    it lends itself better to appending. It is meant for simulations ran entirely separately.
    """
    
    def avg(listt):
        sum = 0
        for i in listt:
            sum += i
        return sum / len(listt)
    
    masslistcopy = masslist.copy() # Don't want to edit the original data
    message = ''
    import os.path
    if kwargs.get('first') or not os.path.isfile(filepath): # If file does not exist, create it. If sys.argv[1]==0,
                                                            #then will also create.
        write_type = "w"
        message += sim+'\n'
        message+="Inner planet mass\tOuter planet mass\tPercent Difference\tSeed\n"
    for data in masslistcopy[1:]:
        #data = data.copy() #comment out this line to not have the original list change
        percentdif = abs((data[0]-data[1])/data[0])*100
        roundedpercentdif = round(percentdif,2)
        data.insert(2,percentdif)
        for j in data:
            message += str(j)
            message +='\t'
        message +='\n'
    with open(filepath,write_type) as file:
        file.write(message)
    if kwargs.get('last') and len(masslist_read(filepath))/4 >= kwargs.get("lastN"):
        with open(filepath, "a") as file:
            file.write("\nAverage percent difference: {}"
                       .format(averagePercent(filepath)))
            file.write("\n"+"#"*40)
# In
def masslist_read(filePath):
    """
    Inverse of masslist_txt()
    """
    with open(filePath,'r') as datafile:
        contents = datafile.read()
    contents = contents.split()
    finalList = []
    for index,value in enumerate(contents):
        try:
            value = float(value)
            finalList.append(value)
            ####contents[index] = value
        except:
            pass
    ####for i in range(0,int(len(contents)), 4):
        ####finalList.append([contents[i:i+4]])
    return finalList
#masslist_read('test.txt')

def avg(listt, **kwargs):
    sum = 0
    length = len(listt)
    if kwargs.get('positive'):
        for i in listt:
            if i > 0:
                sum += i
            else:
                length -= 1
        return sum / length
    if kwargs.get('nonNegative'):
        for i in listt:
            if i >= 0:
                sum += i
            else:
                length -= 1
        return sum / len(listt)
    for i in listt:
        sum += i
    return sum / len(listt)

def averagePercent(filePath):
    dataList = masslist_read(filePath)
    percentList = []
    for i in range(2,len(dataList),4):
        percentList.append(dataList[i])
    return avg(percentList)

# In[4]:

def saveFigs(addOn = "", seed = 0, **kwargs):
    """
    This saves several types of graphs into a folder corresponsing to the seed.
    Optional ability to add on to the name of a file easily.
    NOTE: Depending on the stepnumber, some of these graphs may contain useless data,
    because for some data types the stepnumber needs to be very high.
    """
    if kwargs.get("test"):
        seed = "Tests"
    
    plt.clf() # clears any graphs
    quickplot(sim)
    plt.savefig("Figures/"+str(seed)+"/quickplot"+addOn+".pdf")
    
    plt.clf()
    rebound.OrbitPlot(sim,slices=0.3,color=True)
    plt.savefig("Figures/"+str(seed)+"/reboundPlot"+addOn+".pdf")
    
    plt.clf()
    rebound.OrbitPlot(sim, slices = .3, color = True, lw = 1, plotparticles = [1,2])
    plt.savefig("Figures/"+str(seed)+"/reboundPlotOnlyPlanets"+addOn+".pdf")
    
    plt.clf()
    plt.plot(times, eccs)
    plt.title('Eccentricity Over Time')
    plt.xlabel('Time (2pi*yr)')
    plt.ylabel('Eccentricity')
    plt.savefig("Figures/"+str(seed)+"/Eccentricity"+addOn+".pdf")
    
    plt.clf()
    plt.plot(times, relative_x_value)
    plt.title('X Value From Star Over Time')
    plt.xlabel('Time (2pi*yr)')
    plt.ylabel('X Value (AU)')
    plt.savefig("Figures/"+str(seed)+"/relativeXValue"+addOn+".pdf")
    
    plt.clf()
    plt.plot(times, masses)
    plt.title('Mass of Planets Over Time')
    plt.xlabel('Time (2pi*yr)')
    plt.ylabel('Mass (Solar Masses)')
    plt.savefig("Figures/"+str(seed)+"/masses"+addOn+".pdf")
    
    plt.clf()
    fig, axs = plt.subplots(1, 2)
    fig.suptitle('Planet Positions')
    axs[0].plot(list(position1[:,0]), list(position1[:,1]),'o')
    axs[1].plot(list(position2[:,0]), list(position2[:,1]),'o')
    axs[0].set_aspect('equal')
    axs[1].set_aspect('equal')
    plt.savefig("Figures/"+str(seed)+"/scatterPlotPositions"+addOn+".pdf")
    
    plt.clf()
    plt.plot(times, interplanetdistance)
    plt.title('Interplanetary Distance Over Time')
    plt.xlabel('Time (2pi*yr)')
    plt.ylabel('Distance (AU)')
    plt.savefig("Figures/"+str(seed)+"/interplanetaryDistance"+addOn+".pdf")
    
    plt.clf()
    plt.plot(times, particleNumber)
    plt.title('sim.N over time')
    plt.xlabel('Time (2pi*yr)')
    plt.ylabel('sim.N (AU)')
    plt.savefig("Figures/"+str(seed)+"/particleNumber"+addOn+".pdf")
    
    plt.clf()
    plt.plot(times, asteroidEccs[:,[i for i in range(0,simNi-2-1,10)]], linewidth=1)
    plt.title('Asteroid Eccentricity Over Time')
    plt.xlabel('Time (2pi*yr)')
    plt.ylabel('Eccs')
    plt.savefig("Figures/"+str(seed)+"/RoidEccs"+addOn+".pdf")
    
    plt.clf()
    plt.plot(times, [avg(EccsList, nonNegative = True) for EccsList in asteroidEccs],linewidth=1)
    plt.title('Asteroid Eccentricity AVERAGE Over Time')
    plt.xlabel('Time (2pi*yr)')
    plt.ylabel('Eccentricity')
    plt.savefig("Figures/"+str(seed)+"/RoidEccsAverage"+addOn+".pdf")
    
    plt.clf()
    num_bins = 30
    plt.hist([data for data in asteroidEccs[-1] if data >= 0], num_bins)
    plt.title("Asteroids Final Eccentricity Histogram")
    plt.savefig("Figures/"+str(seed)+"/RoidEccsHistoEnd"+addOn+".pdf")
    
    plt.clf()
    plt.plot(times, asteroidAU[:,[i for i in range(0,simNi-2-1,10)]], linewidth=1)
    # Does not plot every asteroid
    plt.title('Asteroid Semi Major Axis Over Time')
    plt.xlabel('Time (2pi*yr)')
    plt.ylabel('Semi Major Axis (AU)')
    plt.ylim(bottom=-.3, top = 5) # Only want to graph part of escaping asteroids
    plt.savefig("Figures/"+str(seed)+"/RoidSMAxis"+addOn+".pdf")
    
    plt.clf()
    plt.plot(times, [avg(asteroidAUList,positive=True) for asteroidAUList in asteroidAU],linewidth=1)
    plt.title('Asteroid Semi Major Axis AVERAGE Over Time')
    plt.xlabel('Time (2pi*yr)')
    plt.ylabel('Semi Major Axis (AU)')
    plt.savefig("Figures/"+str(seed)+"/RoidSMAxisAverage"+addOn+".pdf")
    
    plt.clf()
    num_bins =30
    plt.hist([data for data in asteroidAU[0] if data > 0 and data < 5], num_bins)
    plt.title("Asteroids Beginning Semi Major Axis Histogram")
    plt.savefig("Figures/"+str(seed)+"/RoidSMAxisHistoStart"+addOn+".pdf")
    
    plt.clf()
    plt.hist([data for data in asteroidAU[-1] if data > 0 and data < 5], num_bins)
    plt.title("Asteroids Ending Semi Major Axis Histogram")
    plt.savefig("Figures/"+str(seed)+"/RoidSMAxisHistoEnd"+addOn+".pdf")
    
###########################################################################################

def generatettor(simulation = ttor,seed = None, asteroidnumber = 1000):  
    sim = simulation()
    sim.N_active = sim.N

    sim.integrator = "ias15"
    #sim.integrator = "whfast"
    #sim.ri_whfast.corrector = 0 #zero order corrector for better speed
    #sim.ri_whfast.safe_mode = 0 #turns off safemode, *substantial* speed boost
    #sim.dt = 0.001*2*np.pi #mutiple by 2pi if in units such that G=1
    sim.testparticle_type = 0
    #sim.ri_ias15.min_dt = 1e-6 # ensure that close encounters do not stall the integration

    #collision and boundary options
    sim.collision = "direct"
    sim.collision_resolve = my_merge
    sim.collision_resolve_keep_sorted = 1
    sim.boundary = "open"
    boxsize = 100
    sim.configure_box(boxsize)
    sim.track_energy_offset = 1

    N_pl = asteroidnumber                # Number of planetesimals
    Mtot_disk = 10*sim.particles[1].m    # Total mass of planetesimal disk
    m_pl = 0 #Mtot_disk / float(N_pl)    # Mass of each planetesimal
    r_pl = 2e-9 

    #seed = 0
    #46 is my most frequently used seed
    np.random.seed(seed) # by setting a seed we will reproduce the same simulation every time
    while sim.N < (N_pl + sim.N_active):
        #a = rand_powerlaw(0, 0.1, 3) 
        a = rand_uniform(.6,2.9)
        #e = rand_rayleigh(0.01) by default is 0
        e=0
        #inc = rand_rayleigh(0.005)
        inc=0
        f = rand_uniform(-np.pi,np.pi)
        p = rebound.Particle(simulation=sim,primary=sim.particles[0], r=r_pl, a=a, e=e, inc=inc, Omega=0, omega=0, f=f)
        # Only add planetesimal if it's far away from the planet
        d1 = np.linalg.norm(np.array(p.xyz)-np.array(sim.particles[1].xyz))
        d2 = np.linalg.norm(np.array(p.xyz)-np.array(sim.particles[2].xyz))
        d = min(d1,d2)
        if d>5e-4:
            sim.add(p)

    # Hash Creation
    ps = sim.particles
    ps[0].hash = "star"
    ps[1].hash = "innerPlanet"
    ps[2].hash = "outerPlanet"
    for i in range(3,sim.N): # this sets their hash to their starting particle number
        ps[i].hash = str(i)

    sim.collision_resolve = my_merge

    #sim.move_to_com()
    global E0
    E0 = sim.calculate_energy()
    #quickplot(sim)
    return sim
    
def quickcollect2(n, Ti, Tf, stepnumber, **kwargs): #collects orbital data on the first two bodies in a system
    initialtime = tiempo.monotonic()
#     n=2 #number of planets
#     T=80*2*np.pi #years of simulation
    # Planet variables
    global times, dist, relative_x_value,relative_y_value, eccs, position1, position2, \
    interplanetdistance, masses, particleNumber
    times = np.linspace(Ti,Tf,stepnumber)
    #diftimes = list()
    dist = np.zeros((len(times),n)) 
    relative_x_value = np.zeros((len(times),n))
    relative_y_value = np.zeros((len(times),n))
    eccs = np.zeros((len(times),n))
    position1 = np.zeros((len(times),2))
    position2 = np.zeros((len(times),2))
    interplanetdistance = np.zeros((len(times),1))
    particleNumber = np.zeros((len(times),1))
    masses = np.zeros((len(times),n))
    ps = sim.particles
    # Asteroid variables:
    global asteroidAU, asteroidEccs, simNi
    simNi = sim.N
    asteroidAU = np.zeros((len(times),simNi-n-1)) # n is the number of planets, 1 is the number of stars
    asteroidEccs = np.zeros((len(times),simNi-n-1))
    #
    print(f"Total steps: {stepnumber}")
    print("| {} time = {} years | {} particles | {} step number |\n| {} second | {} minutes.\n"\
    .format(0,0/tau,sim.N,0,round((tiempo.monotonic()-initialtime),1)\
    ,round((tiempo.monotonic()-initialtime)/60,1)))
    #
    for i, t in enumerate(times):
        sim.integrate(t)
        print("| {} time = {} years | {} particles | {} step number |\n\
| {} second | {} minutes.\n"\
        .format(t,t/tau,sim.N,i,round((tiempo.monotonic()-initialtime),1)\
        ,round((tiempo.monotonic()-initialtime)/60,1)))
        #sim.ri_whfast.recalculate_coordinates_this_timestep = 1
        #sim.integrator_synchronize()
        #diftimes.append(sim.t+dT)
        #if i== int(stepnumber/2):
            #print("1/2 done at {} seconds.".format(int(tiempo.time() - initialtime)))
        ps = sim.particles
        interplanetdistance[i] = np.linalg.norm(np.array(ps[2].xyz)-np.array(ps[1].xyz))
        particleNumber[i] = sim.N
        position1[i] = [ps[1].x,ps[1].y]
        position2[i] = [ps[2].x,ps[2].y]
        for planet in range(n):
            planetdif = planet+1
            dist[i,planet] = np.linalg.norm(np.array(ps[planetdif].xyz)-np.array(ps[0].xyz))
            relative_x_value[i,planet] = ps[planetdif].x - ps[0].x
            relative_y_value[i,planet] = ps[planetdif].y - ps[0].y
            eccs[i,planet] = ps[planetdif].e
            masses[i,planet] = ps[planetdif].m
        position1[i] = [relative_x_value[i,0],relative_y_value[i,0]]
        position2[i] = [relative_x_value[i,1],relative_y_value[i,1]]
        #### Data collection from asteroids:
        if kwargs.get("asteroidCollect"):
            for roidNumber in range(3,simNi):
                #print("index:{}, roidNumber: {}".format(index,roidNumber))
                index = roidNumber - n -1
                try:                    
                    asteroidAU[i,index] = ps[str(roidNumber)].a
                    asteroidEccs[i,index] = ps[str(roidNumber)].e
                except:
                    pass
        ####
    finaltime = tiempo.monotonic()
#     print('done')
    #print("{} done at {} seconds!".format((a+1)/10,int(finaltime-initialtime)))
    print("Done at {} seconds!".format((int(finaltime-initialtime))))
#     print("The inner planet ended with a mass of {}.".format(ps[1].m))
#     print("The outer planet ended with a mass of {}.".format(ps[2].m))
#     print("There are {} particles remaining.".format(sim.N))
    #
    print("| {} time = {} years | {} particles | {} step number |\n| {} second | {} minutes.\n"\
    .format(sim.t,sim.t/tau,sim.N,stepnumber,round((tiempo.monotonic()-initialtime),1)\
    ,round((tiempo.monotonic()-initialtime)/60,1)))
    #
    quickplot(sim)
    #ding()
    
def remove(AU, sim = sim):
    for i in reversed(range(sim.N)):
        ps = sim.particles
        if np.linalg.norm(np.array(ps[i].xyz)-np.array(ps[0].xyz)) > AU:
            sim.remove(i)

# In[20]:

##################################################################################
def batchInfo(*args, **kwargs):
    """
    General info relevant to these batch jobs:
    """
    timesDict = {"seed":"max/min time needed",0:"4h18m",1:"min:9h",2:"time:3h4m",
    3:"time:5h4m",4:"time:3h18m",5:"3h42m",6:"4h30m",7:"4h8m,min:9h",8:"time:4h23m",9:"time:4h32m"}
##################################################################################
#numberOfSims = 1
endTime = 10000 #years of simulation
ttor_masses = [['inner planet mass', 'outer planet mass','seed']]
BIGinitial = tiempo.monotonic()
#
#for a in range(numberOfSims):
a = 15
stepFrequency = 10 # how often should a step occur (years)
steps = int(endTime/stepFrequency) # Will round down to an integer
print(f"Steps: {steps}")
print("Beginning seed {}.".format(a))
sim = generatettor(simulation = ttor, seed =a, asteroidnumber = 5)
quickcollect2(n=2, Ti = 0 * tau, Tf=endTime * tau, stepnumber = steps, asteroidCollect = True) # Can override 'steps' by setting a value directly
ps = sim.particles
print("Masses {} and {}.".format(ps[1].m,ps[2].m))
print("Ending seed {}.\n".format(a))
pre_list = [ps[1].m, ps[2].m,a]
ttor_masses.append(pre_list)
BIGfinal = tiempo.monotonic()
#
totaltime = BIGfinal - BIGinitial
print("That in total took {} seconds ({} minutes).".format(int(totaltime), round(totaltime/60,2)))

#masslist_txt_append(ttor_masses,'Masslists/10000yrTTOR_asteroidDataAsWell.txt','ttor','a', first = first, lastN = lastN)
print(ttor_masses)
print("There are {} particles remaining.".format(sim.N))

saveFigs(seed = a) # the folder witin the figures folder is set with the seed kwarg. Setting seed = "Tests" will
                   # put the figures in the Tests folder (still within Figures)
# Out:
# Steps: 1000
# Beginning seed 15.
# Total steps: 1000
# | 0 time = 0.0 years | 8 particles | 0 step number |
# | 0.0 second | 0.0 minutes.
#
# | 0.0 time = 0.0 years | 8 particles | 0 step number |
# | 0.0 second | 0.0 minutes.
#
# | 62.89474781961548 time = 10.01001001001001 years | 7 particles | 1 step number |
# | 0.0 second | 0.0 minutes.
#
# | 125.78949563923096 time = 20.02002002002002 years | 7 particles | 2 step number |
# | 0.0 second | 0.0 minutes.
#
# | 188.68424345884645 time = 30.030030030030034 years | 7 particles | 3 step number |
# | 0.1 second | 0.0 minutes.
#
# | 251.57899127846193 time = 40.04004004004004 years | 7 particles | 4 step number |
# | 0.1 second | 0.0 minutes.
#
# | 314.47373909807743 time = 50.050050050050054 years | 7 particles | 5 step number |
# | 0.1 second | 0.0 minutes.
#
# | 377.3684869176929 time = 60.06006006006007 years | 7 particles | 6 step number |
# | 0.1 second | 0.0 minutes.
#
# | 440.2632347373084 time = 70.07007007007007 years | 6 particles | 7 step number |
# | 0.1 second | 0.0 minutes.
#
# | 503.15798255692386 time = 80.08008008008008 years | 6 particles | 8 step number |
# | 0.2 second | 0.0 minutes.
#
# | 566.0527303765393 time = 90.0900900900901 years | 6 particles | 9 step number |
# | 0.2 second | 0.0 minutes.
#
# | 628.9474781961549 time = 100.10010010010011 years | 6 particles | 10 step number |
# | 0.2 second | 0.0 minutes.
#
# | 691.8422260157703 time = 110.11011011011011 years | 6 particles | 11 step number |
# | 0.2 second | 0.0 minutes.
#
# | 754.7369738353858 time = 120.12012012012013 years | 6 particles | 12 step number |
# | 0.2 second | 0.0 minutes.
#
# | 817.6317216550012 time = 130.13013013013014 years | 5 particles | 13 step number |
# | 0.2 second | 0.0 minutes.
#
# | 880.5264694746168 time = 140.14014014014015 years | 5 particles | 14 step number |
# | 0.3 second | 0.0 minutes.
#
# | 943.4212172942322 time = 150.15015015015015 years | 5 particles | 15 step number |
# | 0.3 second | 0.0 minutes.
#
# | 1006.3159651138477 time = 160.16016016016016 years | 5 particles | 16 step number |
# | 0.3 second | 0.0 minutes.
#
# | 1069.2107129334631 time = 170.17017017017017 years | 5 particles | 17 step number |
# | 0.3 second | 0.0 minutes.
#
# | 1132.1054607530787 time = 180.1801801801802 years | 5 particles | 18 step number |
# | 0.3 second | 0.0 minutes.
#
# | 1195.0002085726942 time = 190.1901901901902 years | 5 particles | 19 step number |
# | 0.3 second | 0.0 minutes.
#
# | 1257.8949563923097 time = 200.20020020020021 years | 5 particles | 20 step number |
# | 0.3 second | 0.0 minutes.
#
# | 1320.789704211925 time = 210.21021021021022 years | 5 particles | 21 step number |
# | 0.3 second | 0.0 minutes.
#
# | 1383.6844520315406 time = 220.22022022022023 years | 5 particles | 22 step number |
# | 0.3 second | 0.0 minutes.
#
# | 1446.579199851156 time = 230.23023023023023 years | 5 particles | 23 step number |
# | 0.3 second | 0.0 minutes.
#
# | 1509.4739476707716 time = 240.24024024024027 years | 5 particles | 24 step number |
# | 0.3 second | 0.0 minutes.
#
# | 1572.3686954903872 time = 250.25025025025028 years | 5 particles | 25 step number |
# | 0.3 second | 0.0 minutes.
#
# | 1635.2634433100025 time = 260.2602602602603 years | 5 particles | 26 step number |
# | 0.3 second | 0.0 minutes.
#
# | 1698.158191129618 time = 270.27027027027026 years | 5 particles | 27 step number |
# | 0.4 second | 0.0 minutes.
#
# | 1761.0529389492335 time = 280.2802802802803 years | 5 particles | 28 step number |
# | 0.4 second | 0.0 minutes.
#
# | 1823.947686768849 time = 290.29029029029033 years | 5 particles | 29 step number |
# | 0.4 second | 0.0 minutes.
#
# | 1886.8424345884644 time = 300.3003003003003 years | 5 particles | 30 step number |
# | 0.4 second | 0.0 minutes.
#
# | 1949.73718240808 time = 310.31031031031034 years | 5 particles | 31 step number |
# | 0.4 second | 0.0 minutes.
#
# | 2012.6319302276954 time = 320.3203203203203 years | 5 particles | 32 step number |
# | 0.4 second | 0.0 minutes.
#
# | 2075.5266780473107 time = 330.3303303303303 years | 5 particles | 33 step number |
# | 0.4 second | 0.0 minutes.
#
# | 2138.4214258669263 time = 340.34034034034033 years | 5 particles | 34 step number |
# | 0.4 second | 0.0 minutes.
#
# | 2201.316173686542 time = 350.35035035035037 years | 5 particles | 35 step number |
# | 0.4 second | 0.0 minutes.
#
# | 2264.2109215061573 time = 360.3603603603604 years | 5 particles | 36 step number |
# | 0.4 second | 0.0 minutes.
#
# | 2327.105669325773 time = 370.3703703703704 years | 5 particles | 37 step number |
# | 0.4 second | 0.0 minutes.
#
# | 2390.0004171453884 time = 380.3803803803804 years | 5 particles | 38 step number |
# | 0.5 second | 0.0 minutes.
#
# | 2452.895164965004 time = 390.39039039039045 years | 5 particles | 39 step number |
# | 0.5 second | 0.0 minutes.
#
# | 2515.7899127846194 time = 400.40040040040043 years | 5 particles | 40 step number |
# | 0.5 second | 0.0 minutes.
#
# | 2578.684660604235 time = 410.41041041041046 years | 5 particles | 41 step number |
# | 0.5 second | 0.0 minutes.
#
# | 2641.57940842385 time = 420.42042042042044 years | 5 particles | 42 step number |
# | 0.5 second | 0.0 minutes.
#
# | 2704.4741562434656 time = 430.4304304304304 years | 5 particles | 43 step number |
# | 0.5 second | 0.0 minutes.
#
# | 2767.368904063081 time = 440.44044044044045 years | 5 particles | 44 step number |
# | 0.5 second | 0.0 minutes.
#
# | 2830.2636518826966 time = 450.4504504504505 years | 5 particles | 45 step number |
# | 0.5 second | 0.0 minutes.
#
# | 2893.158399702312 time = 460.46046046046047 years | 5 particles | 46 step number |
# | 0.5 second | 0.0 minutes.
#
# | 2956.0531475219277 time = 470.4704704704705 years | 5 particles | 47 step number |
# | 0.5 second | 0.0 minutes.
#
# | 3018.9478953415432 time = 480.48048048048054 years | 5 particles | 48 step number |
# | 0.5 second | 0.0 minutes.
#
# | 3081.842643161159 time = 490.4904904904906 years | 5 particles | 49 step number |
# | 0.5 second | 0.0 minutes.
#
# | 3144.7373909807743 time = 500.50050050050055 years | 5 particles | 50 step number |
# | 0.5 second | 0.0 minutes.
#
# | 3207.6321388003894 time = 510.5105105105105 years | 5 particles | 51 step number |
# | 0.6 second | 0.0 minutes.
#
# | 3270.526886620005 time = 520.5205205205206 years | 5 particles | 52 step number |
# | 0.6 second | 0.0 minutes.
#
# | 3333.4216344396204 time = 530.5305305305305 years | 5 particles | 53 step number |
# | 0.6 second | 0.0 minutes.
#
# | 3396.316382259236 time = 540.5405405405405 years | 5 particles | 54 step number |
# | 0.6 second | 0.0 minutes.
#
# | 3459.2111300788515 time = 550.5505505505506 years | 5 particles | 55 step number |
# | 0.6 second | 0.0 minutes.
#
# | 3522.105877898467 time = 560.5605605605606 years | 5 particles | 56 step number |
# | 0.6 second | 0.0 minutes.
#
# | 3585.0006257180826 time = 570.5705705705707 years | 5 particles | 57 step number |
# | 0.6 second | 0.0 minutes.
#
# | 3647.895373537698 time = 580.5805805805807 years | 5 particles | 58 step number |
# | 0.6 second | 0.0 minutes.
#
# | 3710.7901213573136 time = 590.5905905905906 years | 5 particles | 59 step number |
# | 0.6 second | 0.0 minutes.
#
# | 3773.6848691769287 time = 600.6006006006006 years | 5 particles | 60 step number |
# | 0.6 second | 0.0 minutes.
#
# | 3836.5796169965442 time = 610.6106106106106 years | 5 particles | 61 step number |
# | 0.6 second | 0.0 minutes.
#
# | 
#
# | 6289.474781961549 time = 1001.0010010010011 years | 5 particles | 100 step number |
# | 0.9 second | 0.0 minutes.
#
# | 6352.369529781164 time = 1011.0110110110111 years | 5 particles | 101 step number |
# | 0.9 second | 0.0 minutes.
#
# | 6415.264277600779 time = 1021.021021021021 years | 5 particles | 102 step number |
# | 0.9 second | 0.0 minutes.
#
# | 6478.159025420395 time = 1031.031031031031 years | 5 particles | 103 step number |
# | 0.9 second | 0.0 minutes.
#
# | 6541.05377324001 time = 1041.0410410410411 years | 5 particles | 104 step number |
# | 0.9 second | 0.0 minutes.
#
# | 6603.948521059626 time = 1051.0510510510512 years | 5 particles | 105 step number |
# | 1.0 second | 0.0 minutes.
#
# | 6666.843268879241 time = 1061.061061061061 years | 5 particles | 106 step number |
# | 1.0 second | 0.0 minutes.
#
# | 6729.738016698857 time = 1071.0710710710712 years | 5 particles | 107 step number |
# | 1.0 second | 0.0 minutes.
#
# | 6792.632764518472 time = 1081.081081081081 years | 5 particles | 108 step number |
# | 1.0 second | 0.0 minutes.
#
# | 6855.527512338088 time = 1091.0910910910911 years | 5 particles | 109 step number |
# | 1.0 second | 0.0 minutes.
#
# | 6918.422260157703 time = 1101.1011011011012 years | 5 particles | 110 step number |
# | 1.0 second | 0.0 minutes.
#
# | 6981.317007977318 time = 1111.111111111111 years | 5 particles | 111 step number |
# | 1.0 second | 0.0 minutes.
#
# | 7044.211755796934 time = 1121.1211211211212 years | 5 particles | 112 step number |
# | 1.0 second | 0.0 minutes.
#
# | 7107.106503616549 time = 1131.1311311311313 years | 5 particles | 113 step number |
# | 1.0 second | 0.0 minutes.
#
# | 7170.001251436165 time = 1141.1411411411414 years | 5 particles | 114 step number |
# | 1.0 second | 0.0 minutes.
#
# | 7232.89599925578 time = 1151.1511511511512 years | 5 particles | 115 step number |
# | 1.0 second | 0.0 minutes.
#
# | 7295.790747075396 time = 1161.1611611611613 years | 5 particles | 116 step number |
# | 1.0 second | 0.0 minutes.
#
# | 7358.685494895011 time = 1171.1711711711712 years | 5 particles | 117 step number |
# | 1.0 second | 0.0 minutes.
#
# | 7421.580242714627 time = 1181.1811811811813 years | 5 particles | 118 step number |
# | 1.0 second | 0.0 minutes.
#
# | 7484.474990534242 time = 1191.1911911911914 years | 5 particles | 119 step number |
# | 1.0 second | 0.0 minutes.
#
# | 7547.369738353857 time = 1201.2012012012012 years | 5 particles | 120 step number |
# | 1.1 second | 0.0 minutes.
#
# | 7610.264486173473 time = 1211.2112112112113 years | 5 particles | 121 step number |
# | 1.1 second | 0.0 minutes.
#
# | 7673.1592339930885 time = 1221.2212212212212 years | 5 particles | 122 step number |
# | 1.1 second | 0.0 minutes.
#
# | 7736.0539818127045 time = 1231.2312312312313 years | 5 particles | 123 step number |
# | 1.1 second | 0.0 minutes.
#
# | 7798.94872963232 time = 1241.2412412412414 years | 5 particles | 124 step number |
# | 1.1 second | 0.0 minutes.
#
# | 7861.8434774519355 time = 1251.2512512512515 years | 5 particles | 125 step number |
# | 1.1 second | 0.0 minutes.
#
# | 7924.738225271551 time = 1261.2612612612613 years | 5 particles | 126 step number |
# | 1.1 second | 0.0 minutes.
#
# | 7987.632973091167 time = 1271.2712712712714 years | 5 particles | 127 step number |
# | 1.1 second | 0.0 minutes.
#
# | 8050.527720910782 time = 1281.2812812812813 years | 5 particles | 128 step number |
# | 1.1 second | 0.0 minutes.
#
# | 8113.422468730397 time = 1291.2912912912914 years | 5 particles | 129 step number |
# | 1.1 second | 0.0 minutes.
#
# | 8176.317216550013 time = 1301.3013013013015 years | 5 particles | 130 step number |
# | 1.1 second | 0.0 minutes.
#
# | 8239.211964369628 time = 1311.3113113113113 years | 5 particles | 131 step number |
# | 1.1 second | 0.0 minutes.
#
# | 8302.106712189243 time = 1321.3213213213212 years | 5 particles | 132 step number |
# | 1.1 second | 0.0 minutes.
#
# | 8365.00146000886 time = 1331.3313313313315 years | 5 particles | 133 step number |
# | 1.1 second | 0.0 minutes.
#
# | 8427.896207828475 time = 1341.3413413413414 years | 5 particles | 134 step number |
# | 1.2 second | 0.0 minutes.
#
# | 8490.79095564809 time = 1351.3513513513515 years | 5 particles | 135 step number |
# | 1.2 second | 0.0 minutes.
#
# | 8553.685703467705 time = 1361.3613613613613 years | 5 particles | 136 step number |
# | 1.2 second | 0.0 minutes.
#
# | 8616.580451287322 time = 1371.3713713713717 years | 5 particles | 137 step number |
# | 1.2 second | 0.0 minutes.
#
# | 8679.475199106937 time = 1381.3813813813815 years | 5 particles | 138 step number |
# | 1.2 second | 0.0 minutes.
#
# | 8742.369946926552 time = 1391.3913913913916 years | 5 particles | 139 step number |
# | 1.2 second | 0.0 minutes.
#
# | 8805.264694746167 time = 1401.4014014014015 years | 5 particles | 140 step number |
# | 1.2 second | 0.0 minutes.
#
# | 8868.159442565782 time = 1411.4114114114113 years | 5 particles | 141 step number |
# | 1.2 second | 0.0 minutes.
#
# | 8931.0541903854 time = 1421.4214214214217 years | 5 particles | 142 step number |
# | 1.2 second | 0.0 minutes.
#
# | 8993.948938205014 time = 1431.4314314314315 years | 5 particles | 143 step number |
# | 1.2 second | 0.0 minutes.
#
# | 9056.84368602463 time = 1441.4414414414416 years | 5 particles | 144 step number |
# | 1.2 second | 0.0 minutes.
#
# | 9119.738433844244 time = 1451.4514514514515 years | 5 particles | 145 step number |
# | 1.2 second | 0.0 minutes.
#
# | 9182.633181663861 time = 1461.4614614614618 years | 5 particles | 146 step number |
# | 1.2 second | 0.0 minutes.
#
# | 9245.527929483476 time = 1471.4714714714717 years | 5 particles | 147 step number |
# | 1.2 second | 0.0 minutes.
#
# | 9308.422677303091 time = 1481.4814814814815 years | 5 particles | 148 step number |
# | 1.3 second | 0.0 minutes.
#
# | 9371.317425122706 time = 1491.4914914914916 years | 5 particles | 149 step number |
# | 1.3 second | 0.0 minutes.
#
# | 9434.212172942322 time = 1501.5015015015015 years | 5 particles | 150 step number |
# | 1.3 second | 0.0 minutes.
#
# | 9497.106920761938 time = 1511.5115115115118 years | 5 particles | 151 step number |
# | 1.3 second | 0.0 minutes.
#
# | 9560.001668581554 time = 1521.5215215215217 years | 5 particles | 152 step number |
# | 1.3 second | 0.0 minutes.
step number |
# | 2.1 second | 0.0 minutes.
#
# | 16478.423928739256 time = 2622.6226226226227 years | 5 particles | 262 step number |
# | 2.1 second | 0.0 minutes.
#
# | 16541.318676558873 time = 2632.632632632633 years | 5 particles | 263 step number |
# | 2.1 second | 0.0 minutes.
#
# | 16604.213424378486 time = 2642.6426426426424 years | 5 particles | 264 step number |
# | 2.1 second | 0.0 minutes.
#
# | 16667.108172198103 time = 2652.6526526526527 years | 5 particles | 265 step number |
# | 2.1 second | 0.0 minutes.
#
# | 16730.00292001772 time = 2662.662662662663 years | 5 particles | 266 step number |
# | 2.2 second | 0.0 minutes.
#
# | 16792.897667837333 time = 2672.672672672673 years | 5 particles | 267 step number |
# | 2.2 second | 0.0 minutes.
#
# | 16855.79241565695 time = 2682.6826826826828 years | 5 particles | 268 step number |
# | 2.2 second | 0.0 minutes.
#
# | 16918.687163476563 time = 2692.6926926926926 years | 5 particles | 269 step number |
# | 2.2 second | 0.0 minutes.
#
# | 16981.58191129618 time = 2702.702702702703 years | 5 particles | 270 step number |
# | 2.2 second | 0.0 minutes.
#
# | 17044.476659115797 time = 2712.7127127127133 years | 5 particles | 271 step number |
# | 2.2 second | 0.0 minutes.
#
# | 17107.37140693541 time = 2722.7227227227227 years | 5 particles | 272 step number |
# | 2.2 second | 0.0 minutes.
#
# | 17170.266154755027 time = 2732.732732732733 years | 5 particles | 273 step number |
# | 2.2 second | 0.0 minutes.
#
# | 17233.160902574644 time = 2742.7427427427433 years | 5 particles | 274 step number |
# | 2.2 second | 0.0 minutes.
#
# | 17296.055650394257 time = 2752.7527527527527 years | 5 particles | 275 step number |
# | 2.2 second | 0.0 minutes.
#
# | 17358.950398213874 time = 2762.762762762763 years | 5 particles | 276 step number |
# | 2.2 second | 0.0 minutes.
#
# | 17421.845146033487 time = 2772.772772772773 years | 5 particles | 277 step number |
# | 2.2 second | 0.0 minutes.
#
# | 17484.739893853104 time = 2782.782782782783 years | 5 particles | 278 step number |
# | 2.2 second | 0.0 minutes.
#
# | 17547.63464167272 time = 2792.792792792793 years | 5 particles | 279 step number |
# | 2.3 second | 0.0 minutes.
#
# | 17610.529389492334 time = 2802.802802802803 years | 5 particles | 280 step number |
# | 2.3 second | 0.0 minutes.
#
# | 17673.42413731195 time = 2812.8128128128133 years | 5 particles | 281 step number |
# | 2.3 second | 0.0 minutes.
#
# | 17736.318885131564 time = 2822.8228228228227 years | 5 particles | 282 step number |
# | 2.3 second | 0.0 minutes.
#
# | 17799.21363295118 time = 2832.832832832833 years | 5 particles | 283 step number |
# | 2.3 second | 0.0 minutes.
#
# | 17862.1083807708 time = 2842.8428428428433 years | 5 particles | 284 step number |
# | 2.3 second | 0.0 minutes.
#
# | 17925.00312859041 time = 2852.8528528528527 years | 5 particles | 285 step number |
# | 2.3 second | 0.0 minutes.
#
# | 17987.89787641003 time = 2862.862862862863 years | 5 particles | 286 step number |
# | 2.3 second | 0.0 minutes.
#
# | 18050.79262422964 time = 2872.872872872873 years | 5 particles | 287 step number |
# | 2.3 second | 0.0 minutes.
#
# | 18113.68737204926 time = 2882.882882882883 years | 5 particles | 288 step number |
# | 2.3 second | 0.0 minutes.
#
# | 18176.582119868875 time = 2892.892892892893 years | 5 particles | 289 step number |
# | 2.3 second | 0.0 minutes.
#
# | 18239.47686768849 time = 2902.902902902903 years | 5 particles | 290 step number |
# | 2.3 second | 0.0 minutes.
#
# | 18302.371615508106 time = 2912.9129129129133 years | 5 particles | 291 step number |
# | 2.3 second | 0.0 minutes.
#
# | 18365.266363327723 time = 2922.9229229229236 years | 5 particles | 292 step number |
# | 2.3 second | 0.0 minutes.
#
# | 18428.161111147336 time = 2932.932932932933 years | 5 particles | 293 step number |
# | 2.4 second | 0.0 minutes.
#
# | 18491.055858966953 time = 2942.9429429429433 years | 5 particles | 294 step number |
# | 2.4 second | 0.0 minutes.
#
# | 18553.950606786566 time = 2952.9529529529527 years | 5 particles | 295 step number |
# | 2.4 second | 0.0 minutes.
#
# | 18616.845354606183 time = 2962.962962962963 years | 5 particles | 296 step number |
# | 2.4 second | 0.0 minutes.
#
# | 18679.7401024258 time = 2972.9729729729734 years | 5 particles | 297 step number |
# | 2.4 second | 0.0 minutes.
#
# | 18742.634850245413 time = 2982.9829829829832 years | 5 particles | 298 step number |
# | 2.4 second | 0.0 minutes.
#
# | 18805.52959806503 time = 2992.992992992993 years | 5 particles | 299 step number |
# | 2.4 second | 0.0 minutes.
#
# | 18868.424345884643 time = 3003.003003003003 years | 5 particles | 300 step number |
# | 2.4 second | 0.0 minutes.
#
# | 18931.31909370426 time = 3013.0130130130133 years | 5 particles | 301 step number |
# | 2.4 second | 0.0 minutes.
#
# | 18994.213841523877 time = 3023.0230230230236 years | 5 particles | 302 step number |
# | 2.4 second | 0.0 minutes.
#
# | 19057.10858934349 time = 3033.033033033033 years | 5 particles | 303 step number |
# | 2.4 second | 0.0 minutes.
#
# | 19120.003337163107 time = 3043.0430430430433 years | 5 particles | 304 step number |
# | 2.4 second | 0.0 minutes.
#
# | 19182.89808498272 time = 3053.053053053053 years | 5 particles | 305 step number |
# | 2.4 second | 0.0 minutes.
#
# | 19245.792832802337 time = 3063.063063063063 years | 5 particles | 306 step number |
# | 2.4 second | 0.0 minutes.
#
# | 19308.687580621954 time = 3073.0730730730734 years | 5 particles | 307 step number |
# | 2.5 second | 0.0 minutes.
#
# | 19371.582328441567 time = 3083.0830830830832 years | 5 particles | 308 step number |
# | 2.5 second | 0.0 minutes.
#
# | 19434.477076261184 time = 3093.0930930930936 years | 5 particles | 309 step number |
# | 2.5 second | 0.0 minutes.
#
# | 19497.3718240808 time = 3103.1031031031034 years | 5 particles | 310 step number |
# | 2.5 second | 0.0 minutes.
#
# | 19560.266571900414 time = 3113.1131131131133 years | 5 particles | 311 step number |
# | 2.5 second | 0.0 minutes.
#
# | 19623.16131972003 time = 3123.1231231231236 years | 5 particles | 312 step number |
# | 2.5 second | 0.0 minutes.
#
# | 19686.056067539645 time = 3133.133133133133 years | 5 particles | 313 step number |
# | 2.5 second | 0.0 minutes.
#
# | 19748.95081535926 time = 3143.1431431431433 years | 5 particles | 314 step number |
# | 2.5 second | 0.0 minutes.
#
# | 19811.84556317888 time = 3153.1531531531537 years | 5 particles | 315 step number |
# | 2.5 second | 0.0 minutes.
#
# | 19874.74031099849 time = 3163.163163163163 years | 5 particles | 316 step number |
# | 2.5 second | 0.0 minutes.
#
# | 19937.63505881811 time = 3173.1731731731734 years | 5 particles | 317 step number |
# | 2.5 second | 0.0 minutes.
#
# | 20000.52980663772 time = 3183.1831831831832 years | 5 particles | 318 step number |
# | 2.5 second | 0.0 minutes.
#
# | 20063.42455445734 time = 3193.1931931931936 years | 5 particles | 319 step number |
# | 2.5 second | 0.0 minutes.
#
# | 20126.319302276956 time = 3203.2032032032034 years | 5 particles | 320 step number |
# | 2.5 second | 0.0 minutes.
#
# | 20189.21405009657 time = 3213.2132132132133 years | 5 particles | 321 step number |
# | 2.6 second | 0.0 minutes.
#
# | 20252.108797916186 time = 3223.2232232232236 years | 5 particles | 322 step number |
# | 2.6 second | 0.0 minutes.
#
# | 20315.0035457358 time = 3233.233233233233 years | 5 particles | 323 step number |
# | 2.6 second | 0.0 minutes.
#
# | 20377.898293555416 time = 3243.2432432432433 years | 5 particles | 324 step number |
# | 2.6 second | 0.0 minutes.
#
# | 20440.793041375033 time = 3253.2532532532537 years | 5 particles | 325 step number |
# | 2.6 second | 0.0 minutes.
#
# | 20503.687789194646 time = 3263.2632632632635 years | 5 particles | 326 step number |
# | 2.6 second | 0.0 minutes.
#
# | 20566.582537014263 time = 3273.2732732732734 years | 5 particles | 327 step number |
# | 2.6 second | 0.0 minutes.
#
# | 20629.47728483388 time = 3283.2832832832837 years | 5 particles | 328 step number |
# | 2.6 second | 0.0 minutes.
#
# | 20692.372032653493 time = 3293.2932932932936 years | 5 particles | 329 step number |
# | 2.6 second | 0.0 minutes.
#
# | 20755.26678047311 time = 3303.303303303304 years | 5 particles | 330 step number |
# | 2.6 second | 0.0 minutes.
#
# | 20818.161528292723 time = 3313.3133133133133 years | 5 particles | 331 step number |
# | 2.6 second | 0.0 minutes.
#
# | 20881.05627611234 time = 3323.3233233233236 years | 5 particles | 332 step number |
# | 2.6 second | 0.0 minutes.
#
# | 20943.951023931957 time = 3333.333333333334 years | 5 particles | 333 step number |
# | 2.7 second | 0.0 minutes.
#
# | 21006.84577175157 time = 3343.3433433433433 years | 5 particles | 334 step number |
# | 2.7 second | 0.0 minutes.
#
# | 21069.740519571187 time = 3353.3533533533537 years | 5 particles | 335 step number |
# | 2.7 second | 0.0 minutes.
# | 21132.6352673908 time = 3363.3633633633635 years | 5 particles | 336 step number |
# | 2.7 second | 0.0 minutes.
#
# | 21195.530015210417 time = 3373.3733733733734 years | 5 particles | 337 step number |
# | 2.7 second | 0.0 minutes.
#
# | 21258.424763030034 time = 3383.3833833833837 years | 5 particles | 338 step number |
# | 2.7 second | 0.0 minutes.
#
# | 21321.319510849647 time = 3393.3933933933936 years | 5 particles | 339 step number |
# | 2.7 second | 0.0 minutes.
#
# | 21384.214258669264 time = 3403.403403403404 years | 5 particles | 340 step number |
# | 2.7 second | 0.0 minutes.
#
# | 21447.109006488878 time = 3413.4134134134133 years | 5 particles | 341 step number |
# | 2.7 second | 0.0 minutes.
#
# | 21510.003754308495 time = 3423.4234234234236 years | 5 particles | 342 step number |
# | 2.7 second | 0.0 minutes.
#
# | 21572.89850212811 time = 3433.433433433434 years | 5 particles | 343 step number |
# | 2.7 second | 0.0 minutes.
#
# | 21635.793249947725 time = 3443.4434434434434 years | 5 particles | 344 step number |
# | 2.8 second | 0.0 minutes.
#
# | 21698.68799776734 time = 3453.4534534534537 years | 5 particles | 345 step number |
# | 2.8 second | 0.0 minutes.
#
# | 21761.58274558696 time = 3463.463463463464 years | 5 particles | 346 step number |
# | 2.8 second | 0.0 minutes.
#
# | 21824.47749340657 time = 3473.4734734734734 years | 5 particles | 347 step number |
# | 2.8 second | 0.0 minutes.
#
# | 21887.37224122619 time = 3483.4834834834837 years | 5 particles | 348 step number |
# | 2.8 second | 0.0 minutes.
#
# | 21950.266989045802 time = 3493.4934934934936 years | 5 particles | 349 step number |
# | 2.8 second | 0.0 minutes.
#
# | 22013.16173686542 time = 3503.503503503504 years | 5 particles | 350 step number |
# | 2.8 second | 0.0 minutes.
#
# | 22076.056484685036 time = 3513.5135135135138 years | 5 particles | 351 step number |
# | 2.8 second | 0.0 minutes.
#
# | 22138.95123250465 time = 3523.5235235235236 years | 5 particles | 352 step number |
# | 2.8 second | 0.0 minutes.
#
# | 22201.845980324266 time = 3533.533533533534 years | 5 particles | 353 step number |
# | 2.8 second | 0.0 minutes.
#
# | 22264.74072814388 time = 3543.5435435435434 years | 5 particles | 354 step number |
# | 2.8 second | 0.0 minutes.
#
# | 22327.635475963496 time = 3553.5535535535537 years | 5 particles | 355 step number |
# | 2.9 second | 0.0 minutes.
#
# | 22390.530223783113 time = 3563.563563563564 years | 5 particles | 356 step number |
# | 2.9 second | 0.0 minutes.
#
# | 22453.424971602726 time = 3573.573573573574 years | 5 particles | 357 step number |
# | 2.9 second | 0.0 minutes.
#
# | 22516.319719422343 time = 3583.5835835835837 years | 5 particles | 358 step number |
# | 2.9 second | 0.0 minutes.
#
# | 22579.214467241956 time = 3593.5935935935936 years | 5 particles | 359 step number |
# | 2.9 second | 0.0 minutes.
#
# | 22642.109215061573 time = 3603.603603603604 years | 5 particles | 360 step number |
# | 2.9 second | 0.0 minutes.
#
# | 22705.00396288119 time = 3613.6136136136142 years | 5 particles | 361 step number |
# | 2.9 second | 0.0 minutes.
#
# | 22767.898710700803 time = 3623.6236236236236 years | 5 particles | 362 step number |
# | 2.9 second | 0.0 minutes.
#
# | 22830.79345852042 time = 3633.633633633634 years | 5 particles | 363 step number |
# | 2.9 second | 0.0 minutes.
#
# | 22893.688206340037 time = 3643.6436436436443 years | 5 particles | 364 step number |
# | 2.9 second | 0.0 minutes.
#
# | 22956.58295415965 time = 3653.6536536536537 years | 5 particles | 365 step number |
# | 2.9 second | 0.0 minutes.
#
# | 23019.477701979267 time = 3663.663663663664 years | 5 particles | 366 step number |
# | 3.0 second | 0.0 minutes.
#
# | 23082.37244979888 time = 3673.673673673674 years | 5 particles | 367 step number |
# | 3.0 second | 0.0 minutes.
#
# | 23145.267197618497 time = 3683.6836836836837 years | 5 particles | 368 step number |
# | 3.0 second | 0.0 minutes.
#
# | 23208.161945438114 time = 3693.693693693694 years | 5 particles | 369 step number |
# | 3.0 second | 0.0 minutes.
#
# | 23271.056693257728 time = 3703.703703703704 years | 5 particles | 370 step number |
# | 3.0 second | 0.0 minutes.
#
# | 23333.951441077344 time = 3713.7137137137142 years | 5 particles | 371 step number |
# | 3.0 second | 0.0 minutes.
#
# | 23396.846188896958 time = 3723.7237237237237 years | 5 particles | 372 step number |
# | 3.0 second | 0.1 minutes.
#
# | 23459.740936716575 time = 3733.733733733734 years | 5 particles | 373 step number |
# | 3.0 second | 0.1 minutes.
#
# | 23522.63568453619 time = 3743.7437437437443 years | 5 particles | 374 step number |
# | 3.0 second | 0.1 minutes.
#
# | 23585.530432355805 time = 3753.7537537537537 years | 5 particles | 375 step number |
# | 3.0 second | 0.1 minutes.
#
# | 23648.42518017542 time = 3763.763763763764 years | 5 particles | 376 step number |
# | 3.0 second | 0.1 minutes.
#
# | 23711.319927995035 time = 3773.773773773774 years | 5 particles | 377 step number |
# | 3.0 second | 0.1 minutes.
#
# | 23774.214675814652 time = 3783.783783783784 years | 5 particles | 378 step number |
# | 3.1 second | 0.1 minutes.
#
# | 23837.10942363427 time = 3793.793793793794 years | 5 particles | 379 step number |
# | 3.1 second | 0.1 minutes.
#
# | 23900.004171453882 time = 3803.803803803804 years | 5 particles | 380 step number |
# | 3.1 second | 0.1 minutes.
#
# | 23962.8989192735 time = 3813.8138138138142 years | 5 particles | 381 step number |
# | 3.1 second | 0.1 minutes.
#
# | 24025.793667093116 time = 3823.8238238238246 years | 5 particles | 382 step number |
# | 3.1 second | 0.1 minutes.
#
# | 24088.68841491273 time = 3833.833833833834 years | 5 particles | 383 step number |
# | 3.1 second | 0.1 minutes.
#
# | 24151.583162732346 time = 3843.8438438438443 years | 5 particles | 384 step number |
# | 3.1 second | 0.1 minutes.
#
# | 24214.47791055196 time = 3853.8538538538537 years | 5 particles | 385 step number |
# | 3.1 second | 0.1 minutes.
#
# | 24277.372658371576 time = 3863.863863863864 years | 5 particles | 386 step number |
# | 3.1 second | 0.1 minutes.
#
# | 24340.267406191193 time = 3873.8738738738743 years | 5 particles | 387 step number |
# | 3.1 second | 0.1 minutes.
#
# | 24403.162154010806 time = 3883.883883883884 years | 5 particles | 388 step number |
# | 3.1 second | 0.1 minutes.
#
# | 24466.056901830423 time = 3893.893893893894 years | 5 particles | 389 step number |
# | 3.2 second | 0.1 minutes.
#
# | 24528.951649650036 time = 3903.903903903904 years | 5 particles | 390 step number |
# | 3.2 second | 0.1 minutes.
#
# | 24591.846397469653 time = 3913.9139139139143 years | 5 particles | 391 step number |
# | 3.2 second | 0.1 minutes.
#
# | 24654.74114528927 time = 3923.9239239239246 years | 5 particles | 392 step number |
# | 3.2 second | 0.1 minutes.
#
# | 24717.635893108883 time = 3933.933933933934 years | 5 particles | 393 step number |
# | 3.2 second | 0.1 minutes.
#
# | 24780.5306409285 time = 3943.9439439439443 years | 5 particles | 394 step number |
# | 3.2 second | 0.1 minutes.
#
# | 24843.425388748114 time = 3953.9539539539537 years | 5 particles | 395 step number |
# | 3.2 second | 0.1 minutes.
#
# | 24906.32013656773 time = 3963.963963963964 years | 5 particles | 396 step number |
# | 3.2 second | 0.1 minutes.
#
# | 24969.214884387347 time = 3973.9739739739744 years | 5 particles | 397 step number |
# | 3.2 second | 0.1 minutes.
#
# | 25032.10963220696 time = 3983.983983983984 years | 5 particles | 398 step number |
# | 3.2 second | 0.1 minutes.
#
# | 25095.004380026578 time = 3993.993993993994 years | 5 particles | 399 step number |
# | 3.3 second | 0.1 minutes.
#
# | 25157.899127846194 time = 4004.0040040040044 years | 5 particles | 400 step number |
# | 3.3 second | 0.1 minutes.
#
# | 25220.793875665808 time = 4014.0140140140143 years | 5 particles | 401 step number |
# | 3.3 second | 0.1 minutes.
#
# | 25283.688623485425 time = 4024.0240240240246 years | 5 particles | 402 step number |
# | 3.3 second | 0.1 minutes.
#
# | 25346.583371305038 time = 4034.034034034034 years | 5 particles | 403 step number |
# | 3.3 second | 0.1 minutes.
#
# | 25409.478119124655 time = 4044.0440440440443 years | 5 particles | 404 step number |
# | 3.3 second | 0.1 minutes.
#
# | 25472.37286694427 time = 4054.0540540540546 years | 5 particles | 405 step number |
# | 3.3 second | 0.1 minutes.
#
# | 25535.267614763885 time = 4064.064064064064 years | 5 particles | 406 step number |
# | 3.3 second | 0.1 minutes.
#
# | 25598.1623625835 time = 4074.0740740740744 years | 5 particles | 407 step number |
# | 3.3 second | 0.1 minutes.
#
# | 25661.057110403115 time = 4084.084084084084 years | 5 particles | 408 step number |
# | 3.3 second | 0.1 minutes.
#
# | 25723.951858222732 time = 4094.0940940940945 years | 5 particles | 409 step number |
# | 3.3 second | 0.1 minutes.
#
# | 25786.84660604235 time = 4104.104104104104 years | 5 particles | 410 step number |
# | 3.4 second | 0.1 minutes.
#
# | 25849.741353861962 time = 4114.114114114114 years | 5 particles | 411 step number |
# | 3.4 second | 0.1 minutes.
#
# | 25912.63610168158 time = 4124.124124124124 years | 5 particles | 412 step number |
# | 3.4 second | 0.1 minutes.
#
# | 25975.530849501192 time = 4134.134134134134 years | 5 particles | 413 step number |
# | 3.4 second | 0.1 minutes.
#
# | 26038.42559732081 time = 4144.144144144145 years | 5 particles | 414 step number |
# | 3.4 second | 0.1 minutes.
#
# | 26101.320345140426 time = 4154.154154154155 years | 5 particles | 415 step number |
# | 3.4 second | 0.1 minutes.
#
# | 26164.21509296004 time = 4164.1641641641645 years | 5 particles | 416 step number |
# | 3.4 second | 0.1 minutes.
#
# ...
# | 6.6 second | 0.1 minutes.
#
# | 54215.27262050854 time = 8628.628628628629 years | 4 particles | 862 step number |
# | 6.6 second | 0.1 minutes.
#
# | 54278.16736832816 time = 8638.63863863864 years | 4 particles | 863 step number |
# | 6.6 second | 0.1 minutes.
#
# | 54341.062116147776 time = 8648.648648648648 years | 4 particles | 864 step number |
# | 6.6 second | 0.1 minutes.
#
# | 54403.95686396739 time = 8658.658658658658 years | 4 particles | 865 step number |
# | 6.7 second | 0.1 minutes.
#
# | 54466.85161178701 time = 8668.66866866867 years | 4 particles | 866 step number |
# | 6.7 second | 0.1 minutes.
#
# | 54529.74635960662 time = 8678.67867867868 years | 4 particles | 867 step number |
# | 6.7 second | 0.1 minutes.
#
# | 54592.641107426236 time = 8688.68868868869 years | 4 particles | 868 step number |
# | 6.7 second | 0.1 minutes.
#
# | 54655.53585524586 time = 8698.6986986987 years | 4 particles | 869 step number |
# | 6.7 second | 0.1 minutes.
#
# | 54718.43060306547 time = 8708.70870870871 years | 4 particles | 870 step number |
# | 6.7 second | 0.1 minutes.
#
# | 54781.32535088508 time = 8718.71871871872 years | 4 particles | 871 step number |
# | 6.7 second | 0.1 minutes.
#
# | 54844.2200987047 time = 8728.728728728729 years | 4 particles | 872 step number |
# | 6.7 second | 0.1 minutes.
#
# | 54907.11484652432 time = 8738.738738738739 years | 4 particles | 873 step number |
# | 6.7 second | 0.1 minutes.
#
# | 54970.00959434393 time = 8748.748748748749 years | 4 particles | 874 step number |
# | 6.7 second | 0.1 minutes.
#
# | 55032.90434216354 time = 8758.758758758759 years | 4 particles | 875 step number |
# | 6.7 second | 0.1 minutes.
#
# | 55095.799089983164 time = 8768.76876876877 years | 4 particles | 876 step number |
# | 6.7 second | 0.1 minutes.
#
# | 55158.69383780278 time = 8778.77877877878 years | 4 particles | 877 step number |
# | 6.7 second | 0.1 minutes.
#
# | 55221.58858562239 time = 8788.788788788788 years | 4 particles | 878 step number |
# | 6.8 second | 0.1 minutes.
#
# | 
step number |
# | 7.3 second | 0.1 minutes.
#
# | 60882.11588938779 time = 9689.68968968969 years | 4 particles | 968 step number |
# | 7.3 second | 0.1 minutes.
#
# | 60945.0106372074 time = 9699.6996996997 years | 4 particles | 969 step number |
# | 7.3 second | 0.1 minutes.
#
# | 61007.905385027014 time = 9709.70970970971 years | 4 particles | 970 step number |
# | 7.3 second | 0.1 minutes.
#
# | 61070.800132846634 time = 9719.71971971972 years | 4 particles | 971 step number |
# | 7.3 second | 0.1 minutes.
#
# | 61133.69488066625 time = 9729.72972972973 years | 4 particles | 972 step number |
# | 7.4 second | 0.1 minutes.
#
# | 61196.58962848586 time = 9739.73973973974 years | 4 particles | 973 step number |
# | 7.4 second | 0.1 minutes.
#
# | 61259.48437630548 time = 9749.749749749752 years | 4 particles | 974 step number |
# | 7.4 second | 0.1 minutes.
#
# | 61322.379124125095 time = 9759.75975975976 years | 4 particles | 975 step number |
# | 7.4 second | 0.1 minutes.
#
# | 61385.27387194471 time = 9769.76976976977 years | 4 particles | 976 step number |
# | 7.4 second | 0.1 minutes.
#
# | 61448.16861976433 time = 9779.779779779781 years | 4 particles | 977 step number |
# | 7.4 second | 0.1 minutes.
#
# | 61511.06336758394 time = 9789.789789789791 years | 4 particles | 978 step number |
# | 7.4 second | 0.1 minutes.
#
# | 61573.958115403555 time = 9799.7997997998 years | 4 particles | 979 step number |
# | 7.4 second | 0.1 minutes.
#
# | 61636.852863223176 time = 9809.80980980981 years | 4 particles | 980 step number |
# | 7.4 second | 0.1 minutes.
# | 61699.74761104279 time = 9819.81981981982 years | 4 particles | 981 step number |
# | 7.4 second | 0.1 minutes.
#
# | 61762.6423588624 time = 9829.82982982983 years | 4 particles | 982 step number |
# | 7.4 second | 0.1 minutes.
#
# | 61825.537106682015 time = 9839.83983983984 years | 4 particles | 983 step number |
# | 7.4 second | 0.1 minutes.
#
# | 61888.431854501636 time = 9849.84984984985 years | 4 particles | 984 step number |
# | 7.4 second | 0.1 minutes.
#
# | 61951.32660232125 time = 9859.85985985986 years | 4 particles | 985 step number |
# | 7.4 second | 0.1 minutes.
#
# | 62014.22135014086 time = 9869.86986986987 years | 4 particles | 986 step number |
# | 7.4 second | 0.1 minutes.
#
# | 62077.11609796048 time = 9879.879879879882 years | 4 particles | 987 step number |
# | 7.5 second | 0.1 minutes.
#
# | 62140.010845780096 time = 9889.88988988989 years | 4 particles | 988 step number |
# | 7.5 second | 0.1 minutes.
#
# | 62202.90559359971 time = 9899.8998998999 years | 4 particles | 989 step number |
# | 7.5 second | 0.1 minutes.
#
# | 62265.80034141933 time = 9909.909909909911 years | 4 particles | 990 step number |
# | 7.5 second | 0.1 minutes.
#
# | 62328.69508923894 time = 9919.919919919921 years | 4 particles | 991 step number |
# | 7.5 second | 0.1 minutes.
#
# | 62391.58983705856 time = 9929.929929929931 years | 4 particles | 992 step number |
# | 7.5 second | 0.1 minutes.
#
# | 62454.48458487818 time = 9939.93993993994 years | 4 particles | 993 step number |
# | 7.5 second | 0.1 minutes.
#
# | 62517.37933269779 time = 9949.94994994995 years | 4 particles | 994 step number |
# | 7.5 second | 0.1 minutes.
#
# | 62580.2740805174 time = 9959.95995995996 years | 4 particles | 995 step number |
# | 7.5 second | 0.1 minutes.
#
# | 62643.16882833702 time = 9969.96996996997 years | 4 particles | 996 step number |
# | 7.5 second | 0.1 minutes.
#
# | 62706.06357615664 time = 9979.97997997998 years | 4 particles | 997 step number |
# | 7.5 second | 0.1 minutes.
#
# | 62768.95832397625 time = 9989.98998998999 years | 4 particles | 998 step number |
# | 7.5 second | 0.1 minutes.
#
# | 62831.853071795864 time = 10000.0 years | 4 particles | 999 step number |
# | 7.5 second | 0.1 minutes.
#
# Done at 7 seconds!
# | 62831.853071795864 time = 10000.0 years | 4 particles | 1000 step number |
# | 7.5 second | 0.1 minutes.
#
# Masses 0.00103 and 0.001.
# Ending seed 15.
#
# That in total took 7 seconds (0.13 minutes).
# [['inner planet mass', 'outer planet mass', 'seed'], [0.00103, 0.001, 15]]
# There are 4 particles remaining.

# %%
quickplot(sim)

# %%
sim.particles[0]
# Out:
# <rebound.particle.Particle object at 0x7f9802080950, m=1.0 x=-0.5750406965013769 y=13.625158939861556 z=0.0 vx=0.0015436593194370594 vy=0.000248225023891395 vz=0.0>

# %%
E0
# Out:
# -0.0008154272402872635

# %%
sim.calculate_energy()
# Out:
# -0.0008305216978648222
